# %% [markdown]
# # Survey B

# %% [markdown]
# specify most recent data file(csv from limesurvey) and the directory for output files, leave '' if no csv file wanted

# %%
f = '/scr/liberia1/data/lsd/behavioral/Surveys/surveyB_151013.csv'
ff = '/scr/liberia1/data/lsd/behavioral/Surveys/surveyF_151013.csv' # for getting neo ffi items
out_dir = '/scr/liberia1/data/lsd/behavioral/XNAT'

# %%
execfile('./descrStats_surveys.py')
df = pd.read_csv(f, sep = ",", parse_dates =[1,5])
print 'N =', len(df)
# Out:
# N = 231

# %% [markdown]
# ## Epsworth Sleepiness Scale

# %%
run_ESS(df.copy(), out_dir)
# Out:
# Questionnaire measures general level of sleepiness as the sum of 8 Items
#
# count    231.000000
# mean       8.870130
# std        3.664224
# min        0.000000
# 25%        6.000000
# 50%        9.000000
# 75%       11.000000
# max       19.000000
# Name: ESS_summary_sum, dtype: float64

# %% [markdown]
# ## BDI - Beck Depression Inventory

# %%
run_BDI(df.copy(), out_dir)
# Out:
# For the general population, a score of 21 or over represents depression
#
# count    231.000000
# mean       6.614719
# std        6.113673
# min        0.000000
# 25%        2.000000
# 50%        5.000000
# 75%       10.000000
# max       35.000000
# Name: BDI_summary_sum, dtype: float64

# %% [markdown]
# ## HADS - Hammilton Anxiety and Depression Scale

# %%
run_HADS(df.copy(), out_dir)
# Out:
# rough interpretation:
# 0-7 normal range, 8-10 suggestive presence of mood disorder, >11 probable presence of mood disorder
#
# HADS-A - anxiety
#
# count    231.000000
# mean       5.216450
# std        3.142401
# min        0.000000
# 25%        3.000000
# 50%        5.000000
# 75%        7.000000
# max       14.000000
# Name: HADS-A_summary_sum, dtype: float64
# HADS-D - depression
#
# count    231.000000
# mean       3.640693
# std        3.062521
# min        0.000000
# 25%        1.000000
# 50%        3.000000
# 75%        5.000000
# max       15.000000
# Name: HADS-D_summary_sum, dtype: float64

# %% [markdown]
# ## Boredom Proness Scale

# %%
run_BPS(df.copy(), out_dir)
# Out:
# Questionnaire measures boredom proneness as the sum of 28 items
#
# count    230.000000
# mean      87.504348
# std       18.482317
# min       43.000000
# 25%       74.000000
# 50%       84.000000
# 75%      100.000000
# max      143.000000
# Name: BPS_sum, dtype: float64

# %% [markdown]
# ## Derryberry Attention Control Scale

# %%
run_DAC(df.copy(), out_dir)
# Out:
# count    231.000000
# mean      54.164502
# std        6.957557
# min       38.000000
# 25%       49.000000
# 50%       54.000000
# 75%       58.000000
# max       78.000000
# Name: DAC_sum, dtype: float64

# %% [markdown]
# ## NEO PI R

# %%
run_NEOPIR(f, ff, out_dir)
# Out:
# measure of the Five Factor Model and uses these five dimensions to evaluate adult personality
# – emotional, interpersonal, experiential, attitudinal, and motivational styles –
# 241 items using a 5-point scale
#
# ### NEO Neuroticism ###
# count    147.000000
# mean       1.864551
# std        0.404262
# min        0.978723
# 25%        1.541667
# 50%        1.822222
# 75%        2.136746
# max        3.125000
# Name: NEO_N, dtype: float64
#
# ### NEO Extraversion ###
# count    147.000000
# mean       2.526415
# std        0.347823
# min        1.489362
# 25%        2.319293
# 50%        2.553191
# 75%        2.729167
# max        3.829787
# Name: NEO_E, dtype: float64
# ### NEO Openness (item 83 missing) ###
# count    147.000000
# mean       2.670989
# std        0.382114
# min        1.936170
# 25%        2.369565
# 50%        2.680851
# 75%        2.904255
# max        3.930233
# Name: NEO_O, dtype: float64
#
# ### NEO Agreeableness ###
# count    147.000000
# ...

# %% [markdown]
# ## PSSI - Persönlichkeitsstil- und Störungsinventar

# %%
run_PSSI(df.copy(), out_dir)
# Out:
# ### PSSI_PN: eigenwillig paranoid ###
# count    230.000000
# mean      11.595652
# std        4.480621
# min        2.000000
# 25%        8.250000
# 50%       11.000000
# 75%       14.000000
# max       27.000000
# Name: PSSI_PN, dtype: float64
#
# ### PSSI_SZ: zurückhaltend-schizoid ###
# count    230.000000
# mean       9.691304
# std        4.698361
# min        1.000000
# 25%        6.000000
# 50%        9.000000
# 75%       12.000000
# max       25.000000
# Name: PSSI_SZ, dtype: float64
#
# ### PSSI_ST ahnungsvoll-schizotypisch ###
# count    230.000000
# mean       9.069565
# std        4.857303
# min        1.000000
# 25%        5.000000
# 50%        8.500000
# 75%       12.000000
# max       23.000000
# Name: PSSI_ST, dtype: float64
#
# ### PSSI_BL spontan-borderline ###
# count    230.000000
# mean       6.917391
# std        3.932526
# min        0.000000
# 25%        4.000000
# 50%        6.000000
# 75%        9.000000
# max       20.000000
# ...

# %% [markdown]
# ## MMI - Mulitmedia Multitasking Index

# %%
run_MMI(df.copy(), out_dir)
# Out:
# Questionnaire measures the amount of media used at the same time
# count    229.000000
# mean       4.666492
# std        1.972046
# min        0.259494
# 25%        3.236000
# 50%        4.511316
# 75%        5.707407
# max       12.029652
# Name: MMI, dtype: float64

# %%
run_mobile(df.copy(), out_dir)
