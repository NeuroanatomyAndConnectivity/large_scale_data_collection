# %% [markdown]
# # Survey B

# %%
# specify current version
f = '/scr/liberia1/data/lsd/behavioral/surveyB_151001.csv'

# %%
execfile('./descrStats_surveys.py')
df = pd.read_csv(f, sep = ",", parse_dates =[1,5])
print 'N =', len(df)
# Out:
# N = 233

# %% [markdown]
# ## Epsworth Sleepiness Scale

# %%
run_ESS(df)
# Out:
# Questionnaire measures general level of sleepiness as the sum of 8 Items
#
# count    233.000000
# mean       8.819742
# std        3.689704
# min        0.000000
# 25%        6.000000
# 50%        9.000000
# 75%       11.000000
# max       19.000000
# Name: ESS_summary_sum, dtype: float64

# %% [markdown]
# ## BDI - Beck Depression Inventory

# %%
run_BDI(df.copy())
# Out:
# For the general population, a score of 21 or over represents depression
#
# count    233.000000
# mean       6.433476
# std        6.069007
# min        0.000000
# 25%        2.000000
# 50%        5.000000
# 75%        9.000000
# max       35.000000
# Name: BDI_summary_sum, dtype: float64

# %% [markdown]
# ## HADS - Hammilton Anxiety and Depression Scale

# %%
run_HADS(df.copy())
# Out:
# rough interpretation:
# 0-7 normal range, 8-10 suggestive presence of mood disorder, >11 probable presence of mood disorder
#
# HADS-A - anxiety
#
# count    233.000000
# mean       5.231760
# std        3.134544
# min        0.000000
# 25%        3.000000
# 50%        5.000000
# 75%        7.000000
# max       14.000000
# Name: HADS_summary_HADS-A_sum, dtype: float64
# HADS-D - depression
#
# count    233.000000
# mean       3.682403
# std        3.082555
# min        0.000000
# 25%        1.000000
# 50%        3.000000
# 75%        5.000000
# max       15.000000
# Name: HADS_summary_HADS-D_sum, dtype: float64

# %% [markdown]
# ## Boredom Proness Scale

# %%
run_BPS(df.copy())
# Out:
# Questionnaire measures boredom proneness as the sum of 28 items
#
# count    232.000000
# mean      83.646552
# std       16.612338
# min       45.000000
# 25%       72.000000
# 50%       80.500000
# 75%       94.000000
# max      135.000000
# Name: BPS, dtype: float64

# %% [markdown]
# ## Derryberry Attention Control Scale

# %%
run_DAC(df.copy())
# Out:
# count    233.000000
# mean      53.587983
# std        7.655978
# min       35.000000
# 25%       48.000000
# 50%       54.000000
# 75%       58.000000
# max       79.000000
# Name: DAC, dtype: float64

# %% [markdown]
# ## NEO PI R

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

fileName = '/scr/liberia1/data/lsd/behavioral/surveyB_151001.csv'
df = pd.read_csv(fileName, sep = ",", parse_dates =[1,5])
print 'Survey B N =', len(df)
execfile('/scr/liberia1/data/lsd/behavioral/surveyB.py')
# Out:
# Survey B N = 233

# %%
run_NEOPIR()
# Out:
# measure of the Five Factor Model and uses these five dimensions to evaluate adult personality
# – emotional, interpersonal, experiential, attitudinal, and motivational styles –
# 181 items using a 5-point scale
#
# ### NEO Neuroticism ###
# count    144.000000
# mean       1.872258
# std        0.453633
# min        0.933333
# 25%        1.521739
# 50%        1.811739
# 75%        2.151423
# max        3.285714
# Name: NEO_N, dtype: float64
# ### NEO Extraversion ###
# count    144.000000
# mean       2.601434
# std        0.421555
# min        1.454545
# 25%        2.284799
# 50%        2.638502
# 75%        2.847115
# max        3.911111
# Name: NEO_E, dtype: float64
#
# ### NEO Openness (item 83 missing) ###
# count    144.000000
# mean       2.784261
# std        0.438683
# min        1.926829
# 25%        2.437376
# 50%        2.800214
# 75%        3.085938
# max        4.047619
# Name: NEO_O, dtype: float64
#
# ### NEO Agreeableness ###
# count    144.000000
# ...

# %% [markdown]
# ## PSSI - Persönlichkeitsstil- und Störungsinventar

# %%
run_PSSI(df.copy())
# Out:
# ### PSSI_PN: eigenwillig paranoid ###
# count    232.000000
# mean      11.625000
# std        4.473285
# min        2.000000
# 25%        8.750000
# 50%       11.000000
# 75%       14.000000
# max       27.000000
# Name: PSSI_PN, dtype: float64
#
# ### PSSI_SZ: zurückhaltend-schizoid ###
# count    232.000000
# mean       9.771552
# std        4.757720
# min        1.000000
# 25%        6.000000
# 50%        9.000000
# 75%       12.250000
# max       25.000000
# Name: PSSI_SZ, dtype: float64
#
# ### PSSI_ST ahnungsvoll-schizotypisch ###
# count    232.000000
# mean       9.047414
# std        4.842309
# min        1.000000
# 25%        5.000000
# 50%        8.000000
# 75%       12.000000
# max       23.000000
# Name: PSSI_ST, dtype: float64
#
# ### PSSI_BL spontan-borderline ###
# count    232.000000
# mean       6.922414
# std        3.918324
# min        0.000000
# 25%        4.000000
# 50%        6.000000
# 75%        9.000000
# max       20.000000
# ...

# %%
# MMI

# %%
# Handygebrauch
