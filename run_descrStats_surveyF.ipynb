# %% [markdown]
# # Survey F

# %%
# specify current version
f = '/scr/liberia1/data/lsd/behavioral/surveyF_151001.csv'

# %%
execfile('./descrStats_surveys.py')
df = pd.read_csv(f, sep = ",", parse_dates =[1,5])
print 'N =', len(df)
# Out:
# N = 69

# %% [markdown]
# ## STAI - trait

# %%
run_STAI(df.copy())
# Out:
# count    68.000000
# mean     38.970588
# std      10.318756
# min      25.000000
# 25%      32.000000
# 50%      34.500000
# 75%      43.250000
# max      66.000000
# Name: STAI_A-Trait_summary_sum, dtype: float64

# %% [markdown]
# ## BIS/BAS - behavioral inhibiton/approach

# %%
run_BISBAS(df.copy())
# Out:
# ### BIS ###
# count    68.000000
# mean     20.602941
# std       3.139254
# min      12.000000
# 25%      18.750000
# 50%      21.000000
# 75%      23.000000
# max      27.000000
# Name: BIS, dtype: float64
#
# ### BAS ###
# count    68.000000
# mean     40.382353
# std       3.816810
# min      31.000000
# 25%      38.000000
# 50%      40.000000
# 75%      43.000000
# max      49.000000
# Name: BAS, dtype: float64

# %% [markdown]
# ## STAXI state trait anxiety inventory

# %%
run_STAXI(df.copy())
# Out:
# ### anger_trait ###
# count    68.000000
# mean     17.808824
# std       4.385381
# min      11.000000
# 25%      15.000000
# 50%      17.000000
# 75%      20.000000
# max      30.000000
# Name: anger_trait, dtype: float64
#
# ### anger_inward ###
# count    68.000000
# mean     16.632353
# std       4.944179
# min       8.000000
# 25%      13.000000
# 50%      16.000000
# 75%      20.000000
# max      32.000000
# Name: anger_inward, dtype: float64
#
# ### anger_outward ###
# count    68.000000
# mean     11.985294
# std       3.563885
# min       8.000000
# 25%       9.000000
# 50%      11.000000
# 75%      14.000000
# max      22.000000
# Name: anger_outward, dtype: float64
#
# ### anger_control ###
# count    68.000000
# mean     22.823529
# std       3.851502
# min      11.000000
# 25%      20.000000
# 50%      23.000000
# 75%      25.000000
# max      30.000000
# Name: anger_control, dtype: float64
