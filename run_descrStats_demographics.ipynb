# %%
execfile('./descrStats_demographics.py')
demo_f = '/scr/liberia1/data/lsd/behavioral/Participants_List_LargeScaleProject - Overview_151007.csv'

# %%
run_demographics(demo_f)
# Out:
# #### overall cohort ####
#
# N = 206
# N female = 97
# N male = 108
# /afs/cbs.mpg.de/software/pythonlib/pandas/0.16.1/ubuntu-precise-amd64/lib/python2.7/site-packages/pandas-0.16.1-py2.7-linux-x86_64.egg/pandas/core/indexing.py:118: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# age distribution - female:
# age distribution - male:
# #### young cohort ####
#
# N = 162
# N female = 76
# N male = 86
# age distribution - female:
# age distribution - male:
