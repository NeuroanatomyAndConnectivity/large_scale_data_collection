# %% [markdown]
# # Survey A

# %% [markdown]
# specify most recent data file(csv from limesurvey) and the directory for output files, leave '' if no csv file wanted

# %%
f_in = '/scr/liberia1/data/lsd/behavioral/LimeSurvey/surveyA_151013.csv'
out_dir = '/scr/liberia1/data/lsd/behavioral/XNAT'

# %%
execfile('./descrStats_surveys.py')
df = pd.read_csv(f_in, sep = ",", parse_dates =[1,5])
print 'N =', len(df)
# Out:
# N = 233

# %% [markdown]
# ## Self-Control Scale

# %%
run_SelfCtrl(df.copy(), out_dir)
# Out:
# Questionnaire measures self control (total score is calculated as the sum of the 13 items)
#
# count    233.000000
# mean      41.343348
# std        7.549986
# min       23.000000
# 25%       35.000000
# 50%       42.000000
# 75%       47.000000
# max       60.000000
# Name: SelfCtrl_sum, dtype: float64

# %% [markdown]
# ## FANS I & II

# %% [markdown]
# -- excluded --

# %% [markdown]
# ## Internet Addiction Test

# %%
run_IAT(df.copy(), out_dir)
# Out:
# Questionnaire measures internet addiction (total score is calculated as the sum of the 19 items; Item 3 not incl (different format)
#
# count    233.000000
# mean      36.566524
# std       10.913298
# min       20.000000
# 25%       29.000000
# 50%       34.000000
# 75%       43.000000
# max       72.000000
# Name: IAT_sum, dtype: float64

# %% [markdown]
# ## Varieties of Inner Speech (VIS)

# %%
run_VIS(df.copy(), out_dir)
# Out:
# Questionnaire measures 4 facets of inner speech: dialogic, condensed, other, evaluative
#
# ### dialogic inner speech ###
# count    233.000000
# mean      17.369099
# std        4.142014
# min        4.000000
# 25%       14.000000
# 50%       18.000000
# 75%       20.000000
# max       24.000000
# Name: VIS_dialog_sum, dtype: float64
#
# ### condensed inner speech ###
# count    233.000000
# mean      15.141631
# std        5.412440
# min        5.000000
# 25%       11.000000
# 50%       15.000000
# 75%       19.000000
# max       28.000000
# Name: VIS_condensed_sum, dtype: float64
#
# ### others in inner speech ###
# count    233.000000
# mean       9.128755
# std        5.080447
# min        5.000000
# 25%        5.000000
# 50%        7.000000
# 75%       12.000000
# max       28.000000
# Name: VIS_other_sum, dtype: float64
#
# ### evaluative inner speech ###
# count    233.000000
# mean      16.283262
# std        4.296804
# min        4.000000
# 25%       14.000000
# ...

# %% [markdown]
# ## Mindwandering - spontaneous and deliberate

# %%
run_MW_SD(df.copy(), out_dir)
# Out:
# Questionnaire measures spont/delib MW (subscores are calculated by averaging)
#
# ### MW deliberate ###
# count    233.000000
# mean       3.072961
# std        0.936875
# min        1.000000
# 25%        2.500000
# 50%        3.250000
# 75%        3.750000
# max        5.000000
# Name: Mean_MW_delib_mean, dtype: float64
#
# ### MW spontaneous ###
# count    233.000000
# mean       3.052575
# std        0.933208
# min        1.000000
# 25%        2.500000
# 50%        3.000000
# 75%        3.750000
# max        5.000000
# Name: Mean_MW_spont_mean, dtype: float64

# %% [markdown]
# ## Short Dark Triad

# %%
run_SDT(df.copy(), out_dir)
# Out:
# Questionnaire measures dark triad (Machiavellism, Narcissism, Psychopathy). Scores are sumscores
#
# ### Machiavellism ###
# count    233.000000
# mean      26.566524
# std        4.752141
# min       14.000000
# 25%       23.000000
# 50%       27.000000
# 75%       29.000000
# max       40.000000
# Name: Mach_sum, dtype: float64
#
# ### Narcissism ###
# count    233.000000
# mean      24.472103
# std        4.708791
# min       13.000000
# 25%       22.000000
# 50%       25.000000
# 75%       27.000000
# max       41.000000
# Name: Narc_sum, dtype: float64
#
# ### Psychopathy ###
# count    233.000000
# mean      18.678112
# std        4.389868
# min        9.000000
# 25%       16.000000
# 50%       18.000000
# 75%       22.000000
# max       31.000000
# Name: Psycho_sum, dtype: float64

# %% [markdown]
# ## Social Desirability Scale (SDS)

# %%
run_SES(df.copy(), out_dir)
# Out:
# Questionnaire measure social des. as the sum of 17 items
#
# count    233.000000
# mean      15.939914
# std        3.338102
# min       10.000000
# 25%       13.000000
# 50%       15.000000
# 75%       18.000000
# max       27.000000
# Name: SDS_sum, dtype: float64

# %% [markdown]
# ## UPPSP - impulsivity

# %%
run_UPPSP(df.copy(), out_dir)
# Out:
# Questionnaire measures facets of impuls.: NegUrg, LoPremed, LoPersev, SS, PosUrg (scores are averaged)
#
#
# ### Negative Urgency ###
# count    233.000000
# mean       2.197433
# std        0.452820
# min        1.167000
# 25%        1.917000
# 50%        2.167000
# 75%        2.500000
# max        3.417000
# Name: Mean_NegUrg, dtype: float64
#
# ### Lack of Premed ###
# count    233.00000
# mean       2.05712
# std        0.36870
# min        1.09100
# 25%        1.81800
# 50%        2.09100
# 75%        2.27300
# max        3.09100
# Name: Mean_Premed, dtype: float64
#
# ### Lack of Persev ###
# count    233.000000
# mean       1.945923
# std        0.477144
# min        1.000000
# 25%        1.600000
# 50%        2.000000
# 75%        2.300000
# max        3.200000
# Name: Mean_Persev, dtype: float64
#
# ### SS ###
# count    233.000000
# mean       2.666107
# std        0.595845
# min        1.417000
# 25%        2.250000
# 50%        2.750000
# 75%        3.083000
# ...

# %% [markdown]
# ## Tuckmann Procrastination Scale (TPS-D)

# %%
run_TPS(df.copy(), out_dir)
# Out:
# Questionnaire measures procrastination as the sum of 16 items
#
# count    233.000000
# mean      45.364807
# std       13.272345
# min       17.000000
# 25%       35.000000
# 50%       44.000000
# 75%       55.000000
# max       75.000000
# Name: TPS_D_sum, dtype: float64

# %% [markdown]
# ## ASR

# %%
run_ASR(df.copy(), out_dir)
# Out:
# The Adult Self-Report (ASR; part of the Achenbach System of Empirically Based Assessment)
#
# Adaptive Functioning Scales:
# Friends; Spouse/Partner; Family; Job; Education, Personal Strengths
#
# Substance Use Scales:
# Tobacco, Alcohol, Drugs, mean substance use
#
# Syndrome Scales (123 items on a 3-point scale):
# Anxious/Depressed; Withdrawn; Somatic Complaints (together form the Internalizing scale)
# Aggressive Behavior; Rule-breaking Behavior, and Intrusive (form the Externalzing scale)
# Thought Problems; Attention Problems
#
#
# ##### Adaptive Functioning #####
# count    231.000000
# mean       8.991342
# std        2.130506
# min        0.000000
# 25%        8.000000
# 50%        9.000000
# 75%       11.000000
# max       12.000000
# Name: ASR_summary_adaptiveFunctioning_friends_sum, dtype: float64
# ...

# %% [markdown]
# ## Self-Esteem Scale

# %%
run_SelfEst(df.copy(), out_dir)
# Out:
# Questionnaire measure self-esteem as the mean of 8 items
#
# count    233.000000
# mean       4.231223
# std        0.646492
# min        2.000000
# 25%        3.875000
# 50%        4.375000
# 75%        4.750000
# max        5.000000
# Name: Mean_SelfEst, dtype: float64

# %% [markdown]
# ## Involuntary Musical Imagery Scale (Earworm Scale)

# %%
run_IMIS(df.copy(), out_dir)
# Out:
# Involuntary Musical Imagery Scale (IMIS)
#
#
# An Involuntary Musical Imagery (INMI) episode is the
#  experience of a repetition of a short music loop in one s head,
#  unbidden to the mind and without conscious control
#  INMI are also called Earworms.
#
# Frequency of INMI episodes
# count    233.000000
# mean       3.283262
# std        1.112826
# min        1.000000
# 25%        2.000000
# 50%        3.000000
# 75%        4.000000
# max        6.000000
# Name: EWSaBASEQ[AQ_1], dtype: float64
#
#
# All subsequent reported scores are for participants who reported experiencing INMI
#  (answer to the frequency question different from "never" = 1)
#
#
# Section length (length of music loop experienced as INMI)
# count    220.000000
# mean       2.554545
# std        0.860990
# min        1.000000
# 25%        2.000000
# 50%        2.000000
# 75%        3.000000
# max        5.000000
# Name: EWSdBASEQ[AQ2], dtype: float64
#
#
# Episode length
# count    220.000000
# ...

# %% [markdown]
# ## Goldsmith's Musical Sophistication Index (Aktiver Umgang mit Musik)

# %%
run_GoldMSI(df.copy(), out_dir)
# Out:
# Goldsmiths Musical Sophistication Index (Gold-MSI)
#
#
# Active Engagement in Musical Activities:
#
# count    233.000000
# mean      33.278970
# std       10.367154
# min       10.000000
# 25%       25.000000
# 50%       34.000000
# 75%       41.000000
# max       59.000000
# Name: GoldMSI_Active_sum, dtype: float64
#
#
# Musical Training:
#
# count    233.000000
# mean      21.721030
# std       10.468933
# min        9.000000
# 25%       12.000000
# 50%       21.000000
# 75%       31.000000
# max       46.000000
# Name: GoldMSI_Training_sum, dtype: float64

# %% [markdown]
# ## Gender Identity Questionnaire

# %% [markdown]
# no sum socres, only csv output for xnat

# %%
run_GIQ(df.copy(), out_dir)
