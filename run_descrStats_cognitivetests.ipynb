# %% [markdown]
# # Cognitive Tests

# %% [markdown]
# specify current data file and directory for output files, leave empty quotes if no output csv wanted

# %%
f_in = '/scr/liberia1/data/lsd/behavioral/LSD_CB_151007.csv'

# %%
execfile('./descrStats_cognitivetests.py')
df = pd.read_csv(f_in, sep = ",", skiprows = 1)
print 'N =', len(df['db ID'].dropna())
# Out:
# N = 167

# %% [markdown]
# ## Trail Making Test

# %%
run_TMT(df.copy())
# Out:
# TMT_A: numbers: seconds
# count    156.000000
# mean      26.231154
# std        8.352997
# min       10.910000
# 25%       21.315000
# 50%       25.155000
# 75%       29.205000
# max       58.340000
# Name: TMT_A_numbers_seconds, dtype: float64
#
# TMT_A: numbers: errors
# count    156.000000
# mean       0.160256
# std        0.526667
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        4.000000
# Name: TMT_A_numbers_errors, dtype: float64
# at least one error: N = 18
#
# TMT_B: Numbers-Letters: seconds
# count    155.000000
# mean      53.404129
# std       18.837374
# min       16.440000
# 25%       40.705000
# 50%       50.310000
# 75%       61.065000
# max      139.090000
# Name: TMT_B_numbersletters_seconds, dtype: float64
#
# TMT_B: Numbers-Letters: errors
# count    156.000000
# mean       0.275641
# std        0.696292
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# ...

# %% [markdown]
# ## Wortschatztest

# %%
run_WST(df.copy())
# Out:
# Measure of verbal intelligence: Task: find real words; Max = 42
#
# WST raw scores
# count    156.000000
# mean      33.262821
# std        2.742996
# min       23.000000
# 25%       32.000000
# 50%       34.000000
# 75%       35.000000
# max       39.000000
# Name: WST_RW, dtype: float64

# %% [markdown]
# ## Leistungsprüfsystem Subtest 3

# %%
run_LPS(df.copy())
# Out:
# Measure of reasoning: Task: find correct symbol; Max = 40
#
# LPS raw scores
# count    156.000000
# mean      21.192308
# std        3.538025
# min        9.000000
# 25%       19.000000
# 50%       21.000000
# 75%       23.000000
# max       32.000000
# Name: LPS_RW, dtype: float64

# %% [markdown]
# ## Regensburger Wortflüssigkeitstests

# %%
run_RWT(df.copy())
# Out:
# measures verbal fluency: Task: find as many words as you can from a category or with a certain letter
#
# S-words: Raw scores: sum across 2 minutes
# count    156.000000
# mean      24.961538
# std        6.691241
# min        8.000000
# 25%       20.000000
# 50%       25.000000
# 75%       29.250000
# max       42.000000
# Name: Wörter_Summe_min, dtype: float64
#
# Repetitions S-words across 2 minutes
# count    156.000000
# mean       0.826923
# std        1.102276
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        1.000000
# max        7.000000
# Name: Wörter_Summe_R, dtype: float64
# at least one rep: N(subjects) = 80
#
# rule books s-words
# count    156.000000
# mean       0.230769
# std        0.620574
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        5.000000
# Name: Wörter_Summe_RB, dtype: float64
# at least one rule book: N(subjects) = 27
#
# ANIMALS: Raw scores: sum across 2 minutes
# ...

# %% [markdown]
# ## TAP - Testbatterie zur Aufmerksamkeitsprüfung (Alertness, Incompatibility, Working Memory)

# %% [markdown]
# ## Alertness

# %%
run_TAP(df.copy())
# Out:
# Task: press button when target stim appears on screen; two conditions: with and without prime (tone)
# two runs for each condition
#
#
# ALERT: condition without signal - mean RTs
# count    156.000000
# mean     217.288462
# std       27.973953
# min      165.000000
# 25%      198.750000
# 50%      213.000000
# 75%      229.000000
# max      360.000000
# Name: Alert_no_sig_Mean, dtype: float64
#
# ALERT: condition with signal - mean RTs
# count    156.000000
# mean     217.333333
# std       30.224180
# min      157.000000
# 25%      196.750000
# 50%      216.000000
# 75%      230.000000
# max      355.000000
# Name: Alert_sig_Mean, dtype: float64
# Task: button press left/right depending on which side an arrow points (ignore on which side target appears)
# two runs for each condition - congruent/incongruent
#
#
# INCOMPAT: congruent - mean RTs
# count    156.000000
# mean     411.878205
# std       77.817350
# min       69.000000
# 25%      365.750000
# 50%      401.000000
# ...
