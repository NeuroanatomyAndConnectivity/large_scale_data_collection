# %% [markdown]
# # Meta-level information

# %%
execfile('./descrStats_metalevel-info.py')

survA_f = '/scr/liberia1/data/lsd/behavioral/Surveys/surveyA_151013.csv'
survB_f = '/scr/liberia1/data/lsd/behavioral/Surveys/surveyB_151013.csv'
survC_active_f = '/scr/liberia1/data/lsd/behavioral/Surveys/surveyCactive_151013.csv'
survC_inactive_f = '/scr/liberia1/data/lsd/behavioral/Surveys/surveyCinactive_151013.csv'
survC_corrected_f = '/scr/liberia1/data/lsd/behavioral/Surveys/surveyCcorrected_151013.csv'
survF_f = '/scr/liberia1/data/lsd/behavioral/Surveys/surveyF_151013.csv'
survG_f = '/scr/liberia1/data/lsd/behavioral/Surveys/surveyG_151013.csv'
edu_f = '/scr/liberia1/data/lsd/behavioral/metaInfo/education.csv'
task_Hannes_f = '/scr/liberia1/data/lsd/behavioral/metaInfo/Participants_List_LargeScaleProject - Test_phase#4_20151208.csv'
task_cogntests_f = '/scr/liberia1/data/lsd/behavioral/metaInfo/Participants_List_LargeScaleProject - Test_phase#6_20151208.csv'
skid_drug_f = '/scr/liberia1/data/lsd/behavioral/metaInfo/Participants_List_LargeScaleProject - Overview_20151208.csv'
drug_f = '/scr/liberia1/data/lsd/behavioral/metaInfo/LSD before MRI Physio & Drug_20151210.csv'
lemon_scan_f = '/scr/liberia1/data/lsd/behavioral/metaInfo/LEMON scan day_20151214.csv'

out_dir = '/scr/liberia1/data/lsd/behavioral/XNAT'

# %%
df = run_metainfo(survA_f, survB_f, survC_active_f, survC_inactive_f, survC_corrected_f, survF_f, 
                  survG_f, task_Hannes_f, task_cogntests_f, edu_f, skid_drug_f, drug_f, lemon_scan_f, out_dir)

# %% [markdown]
# ## Demograhpics

# %%
run_demographics(df)
# Out:
# #### overall cohort, at time of scanning ####
#
# N = 346
# N female = 112
# N male = 127
# age distribution - female:
# age distribution - male:
# #### young cohort, A ####
#
# N = 182
# N female = 83
# N male = 99
# age distribution - female:
# age distribution - male:
# #### young cohort, B ####
#
# N = 181
# N female = 84
# N male = 97
# age distribution - female:
# age distribution - male:
# #### young cohort, C ####
#
# N = 164
# N female = 75
# N male = 89
# age distribution - female:
# age distribution - male:
# #### young cohort, F ####
#
# N = 66
# N female = 36
# N male = 30
# age distribution - female:
# age distribution - male:
# #### young cohort, G ####
#
# N = 77
# N female = 28
# N male = 49
# age distribution - female:
# age distribution - male:
# #### young cohort, Hannes ####
#
# N = 136
# N female = 62
# N male = 74
# age distribution - female:
# age distribution - male:
# #### young cohort, CognTests ####
#
# N = 63
# N female = 35
# N male = 28
# age distribution - female:
# age distribution - male:
# #### young cohort, LEMON ####
#
# N = 90
# N female = 34
# N male = 56
# age distribution - female:
# age distribution - male:

# %% [markdown]
# ## Study time course

# %% [markdown]
# ### time intervals in days, reference point: day of scanning

# %%
run_studycourse(df)
# Out:
# Survey A
# number of days between scanning and survey
#
# 	mean: 38.0097087379
# 	median: 18.5
# 	stand. dev.: 43.781496291
# Survey B
# number of days between scanning and survey
#
# 	mean: 32.6571428571
# 	median: 14.0
# 	stand. dev.: 40.3069154957
# Survey F
# number of days between scanning and survey
#
# 	mean: 151.573529412
# 	median: 172.5
# 	stand. dev.: 99.2542816365
# Survey G
# number of days between scanning and survey
#
# 	mean: 130.75
# 	median: 11.0
# 	stand. dev.: 147.215590207
# Survey Hannes
# number of days between scanning and survey
#
# 	mean: 149.746376812
# 	median: 143.5
# 	stand. dev.: 131.521087737
# Survey CognTests
# number of days between scanning and survey
#
# 	mean: 187.153846154
# 	median: 193.0
# 	stand. dev.: 112.805312204
# Survey LEMON
# number of days between scanning and survey
#
# 	mean: 186.306306306
# 	median: 143.0
# 	stand. dev.: 139.9430269
