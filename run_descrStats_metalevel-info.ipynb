# %% [markdown]
# # Meta-level information

# %%
execfile('./descrStats_metalevel-info.py')

survA_f = '/scr/liberia1/data/lsd/behavioral/Surveys/surveyA_151013.csv'
survB_f = '/scr/liberia1/data/lsd/behavioral/Surveys/surveyB_151013.csv'
survC_active_f = '/scr/liberia1/data/lsd/behavioral/Surveys/surveyCactive_151013.csv'
survC_inactive_f = '/scr/liberia1/data/lsd/behavioral/Surveys/surveyCinactive_151013.csv'
survC_corrected_f = '/scr/liberia1/data/lsd/behavioral/Surveys/surveyCcorrected_151013.csv'
survF_f = '/scr/liberia1/data/lsd/behavioral/Surveys/surveyF_151013.csv'
survG_f = '/scr/liberia1/data/lsd/behavioral/Surveys/surveyG_151013.csv'
edu_f = '/scr/liberia1/data/lsd/behavioral/metaInfo/education.csv'
task_Hannes_f = '/scr/liberia1/data/lsd/behavioral/metaInfo/Participants_List_LargeScaleProject - Test_phase#4_20151215.csv'
task_cogntests_f = '/scr/liberia1/data/lsd/behavioral/metaInfo/Participants_List_LargeScaleProject - Test_phase#6_20151215.csv'
skid_f = '/scr/liberia1/data/lsd/behavioral/metaInfo/Participants_List_LargeScaleProject - Overview_20151215.csv'
physio_f = '/scr/liberia1/data/lsd/behavioral/metaInfo/Lemon-Connect MRT-LSD database participants_pressure_pulse.ods - Sheet1_20151215.csv'
lemon_days_f = '/scr/liberia1/data/lsd/behavioral/metaInfo/LEMON appointments_20151216.csv'

out_dir = '/scr/liberia1/data/lsd/behavioral/XNAT'

# %%
df = run_metainfo(survA_f, survB_f, survC_active_f, survC_inactive_f, survC_corrected_f, survF_f, 
                  survG_f, task_Hannes_f, task_cogntests_f, edu_f, skid_f, physio_f, lemon_days_f, out_dir)

# %% [markdown]
# ## Demograhpics

# %%
run_demographics(df)
# Out:
# #### overall cohort, at time of scanning ####
#
# N = 233
# N female = 109
# N male = 124
# age distribution - female:
# age distribution - male:
# #### young cohort, age day 1 ####
#
# N = 182
# N female = 83
# N male = 99
# age distribution - female:
# age distribution - male:
# #### young cohort, age day 2 ####
#
# N = 176
# N female = 81
# N male = 95
# age distribution - female:
# age distribution - male:
# #### young cohort, age day 3 ####
#
# N = 160
# N female = 73
# N male = 87
# age distribution - female:
# age distribution - male:
# #### young cohort, age day 4 ####
#
# N = 136
# N female = 62
# N male = 74
# age distribution - female:
# age distribution - male:
# #### young cohort, age day 5a ####
#
# N = 66
# N female = 36
# N male = 30
# age distribution - female:
# age distribution - male:
# #### young cohort, age day 5b ####
#
# N = 77
# N female = 28
# N male = 49
# age distribution - female:
# age distribution - male:
# #### young cohort, age day 6 ####
#
# N = 63
# ...

# %% [markdown]
# ## Study time course

# %% [markdown]
# ### time intervals in days, reference point: day of scanning

# %%
run_studycourse(df)
# Out:
# Survey 1
# number of days between scanning and survey
#
# 	mean: 38.0097087379
# 	median: 18.5
# 	stand. dev.: 43.781496291
# Survey 2
# number of days between scanning and survey
#
# 	mean: 31.7512195122
# 	median: 14.0
# 	stand. dev.: 40.3622270633
# Survey 4
# number of days between scanning and survey
#
# 	mean: 149.746376812
# 	median: 143.5
# 	stand. dev.: 131.521087737
# Survey 5a
# number of days between scanning and survey
#
# 	mean: 151.573529412
# 	median: 172.5
# 	stand. dev.: 99.2542816365
# Survey 5b
# number of days between scanning and survey
#
# 	mean: 130.75
# 	median: 11.0
# 	stand. dev.: 147.215590207
# Survey 6
# number of days between scanning and survey
#
# 	mean: 187.153846154
# 	median: 193.0
# 	stand. dev.: 112.805312204
# Survey LEMON 1
# number of days between scanning and survey
#
# 	mean: 167.504504505
# 	median: 137.0
# 	stand. dev.: 113.968566151
